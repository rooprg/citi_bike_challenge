# %%
import pandas as pd

# %%
# Compile datasets into a single .csv file
files = ['JC-202206-citibike-tripdata.csv',
         'JC-202212-citibike-tripdata.csv']

# %%
#Create an new DF to house the data
roop_bike_df = pd.DataFrame()

# %%
# Loop through files to compile data
for file in files:
    data = pd.read_csv(file)
    roop_bike_df = pd.concat([roop_bike_df, data], axis=0)

# %%
# Show new DF
roop_bike_df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      EEA3CD3B084370F4   classic_bike  2022-06-30 19:17:16
# 1      BF568C9B3C5FAE94   classic_bike  2022-06-02 12:46:44
# 2      DF6B06D460481A7E   classic_bike  2022-06-05 14:17:34
# 3      A26CDB92CDF7E0EE  electric_bike  2022-06-01 18:57:12
# 4      A2A50E81031E9E7F  electric_bike  2022-06-14 22:45:53
# ...                 ...            ...                  ...
# 48580  D438F1622839AC50   classic_bike  2022-12-06 15:43:38
# 48581  747A63A8E782D171  electric_bike  2022-12-08 08:17:51
# 48582  AE090858CFDE6E82  electric_bike  2022-12-23 14:10:07
# 48583  B3CC8E70AF4E259C   classic_bike  2022-12-02 04:43:25
# 48584  176B601F21327350   classic_bike  2022-12-30 14:50:17
#
#                   ended_at                      start_station_name  \
# 0      2022-06-30 19:27:13                  Clinton St & Newark St
# 1      2022-06-02 15:08:33                  Clinton St & Newark St
# ...

# %%
# Dropping rows with missing values
roop_bike_df.dropna(subset = ['end_station_id', 'end_lat', 'end_lng'], inplace=True)

# %%
# Checking for updates to row count
roop_bike_df
# Out:
#                 ride_id  rideable_type           started_at  \
# 0      EEA3CD3B084370F4   classic_bike  2022-06-30 19:17:16
# 1      BF568C9B3C5FAE94   classic_bike  2022-06-02 12:46:44
# 2      DF6B06D460481A7E   classic_bike  2022-06-05 14:17:34
# 3      A26CDB92CDF7E0EE  electric_bike  2022-06-01 18:57:12
# 4      A2A50E81031E9E7F  electric_bike  2022-06-14 22:45:53
# ...                 ...            ...                  ...
# 48580  D438F1622839AC50   classic_bike  2022-12-06 15:43:38
# 48581  747A63A8E782D171  electric_bike  2022-12-08 08:17:51
# 48582  AE090858CFDE6E82  electric_bike  2022-12-23 14:10:07
# 48583  B3CC8E70AF4E259C   classic_bike  2022-12-02 04:43:25
# 48584  176B601F21327350   classic_bike  2022-12-30 14:50:17
#
#                   ended_at                      start_station_name  \
# 0      2022-06-30 19:27:13                  Clinton St & Newark St
# 1      2022-06-02 15:08:33                  Clinton St & Newark St
# ...

# %%
cleaned_roop_df = roop_bike_df.rename(columns={"ride_id":"ID", "rideable_type":"Bike Type", "started_at":"Start Time",
                                               "ended_at":"End Time", "start_station_name":"Start Station", "start_station_id":"Start Station ID",
                                               "end_station_name":"End Station Name", "end_station_id":"End Station ID", "start_lat":"Latitude1",
                                               "start_lng":"Longitude1", "end_lat":"Latitude2", "end_lng":"Longitude2", "member_casual":"Rental type" })

# %%
cleaned_roop_df
# Out:
#                      ID      Bike Type           Start Time  \
# 0      EEA3CD3B084370F4   classic_bike  2022-06-30 19:17:16
# 1      BF568C9B3C5FAE94   classic_bike  2022-06-02 12:46:44
# 2      DF6B06D460481A7E   classic_bike  2022-06-05 14:17:34
# 3      A26CDB92CDF7E0EE  electric_bike  2022-06-01 18:57:12
# 4      A2A50E81031E9E7F  electric_bike  2022-06-14 22:45:53
# ...                 ...            ...                  ...
# 48580  D438F1622839AC50   classic_bike  2022-12-06 15:43:38
# 48581  747A63A8E782D171  electric_bike  2022-12-08 08:17:51
# 48582  AE090858CFDE6E82  electric_bike  2022-12-23 14:10:07
# 48583  B3CC8E70AF4E259C   classic_bike  2022-12-02 04:43:25
# 48584  176B601F21327350   classic_bike  2022-12-30 14:50:17
#
#                   End Time                           Start Station  \
# 0      2022-06-30 19:27:13                  Clinton St & Newark St
# 1      2022-06-02 15:08:33                  Clinton St & Newark St
# ...

# %%
# Creating output
cleaned_roop_df.to_csv("cleaned_roop_bike_data.csv", index=False, header=True)
